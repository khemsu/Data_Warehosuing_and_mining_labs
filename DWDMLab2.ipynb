# %% [markdown]
# <a href="https://colab.research.google.com/github/khemsu/Data_Warehosuing_and_mining_labs/blob/main/DWDMLab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Apriori Algorithm
# For space.txt

# %%
from google.colab import files
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Upload the .txt file
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Read file and extract transactions
transactions = []
with open(filename, 'r') as file:
    lines = file.readlines()[1:]  # skip header
    for line in lines:
        parts = line.strip().split(',')
        items = [item.strip().lower() for item in parts[1:] if item.strip()]
        transactions.append(items)

te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_array, columns=te.columns_)

# Minimum support threshold (adjust as needed)
frequent_itemsets = apriori(df, min_support=0.2, use_colnames=True)

print("🔸 Frequent Itemsets with Support:")
print(frequent_itemsets.sort_values(by="support", ascending=False))

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

print("\n🔹 Association Rules (Confidence ≥ 60%):")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].sort_values(by='lift', ascending=False))
# Out:
#      <input type="file" id="files-10f2241a-a056-45f3-9b23-71709c0cabee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10f2241a-a056-45f3-9b23-71709c0cabee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# For Sports.txt

# %%
from google.colab import files
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Upload the .txt file
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Read file and extract transactions
transactions = []
with open(filename, 'r') as file:
    lines = file.readlines()[1:]  # skip header
    for line in lines:
        parts = line.strip().split(',')
        items = [item.strip().lower() for item in parts[1:] if item.strip()]
        transactions.append(items)

te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_array, columns=te.columns_)

# Minimum support threshold (adjust as needed)
frequent_itemsets = apriori(df, min_support=0.2, use_colnames=True)

print("🔸 Frequent Itemsets with Support:")
print(frequent_itemsets.sort_values(by="support", ascending=False))

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

print("\n🔹 Association Rules (Confidence ≥ 60%):")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].sort_values(by='lift', ascending=False))
# Out:
#      <input type="file" id="files-ece6e036-09a0-45a4-a685-a76d3655348b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ece6e036-09a0-45a4-a685-a76d3655348b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## FP-Growth algorithm
# For space.txt

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules
from google.colab import files

# STEP 1: Upload the .txt file
uploaded = files.upload()

# STEP 2: Read and preprocess the uploaded text file
filename = list(uploaded.keys())[0]

# Read file and skip the header
transactions = []
with open(filename, 'r') as file:
    lines = file.readlines()[1:]  # Skip header line
    for line in lines:
        parts = line.strip().split(',')
        # Skip Transaction ID, only keep items
        items = [item.strip().lower() for item in parts[1:] if item.strip()]
        transactions.append(items)

# STEP 3: Encode transactions into dataframe
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# STEP 4: Find frequent itemsets using FP-Growth
frequent_itemsets = fpgrowth(df, min_support=0.2, use_colnames=True)  # 20% support threshold
print("🔸 Frequent Itemsets with Support:")
print(frequent_itemsets.sort_values(by="support", ascending=False))

# STEP 5: Compute confidence and lift
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
print("\n🔹 Association Rules (Confidence >= 60%):")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].sort_values(by="lift", ascending=False))
# Out:
#      <input type="file" id="files-929b8422-3004-4b77-9caf-43a40fc6a4c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-929b8422-3004-4b77-9caf-43a40fc6a4c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# For sports.txt

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules
from google.colab import files

# STEP 1: Upload the .txt file
uploaded = files.upload()

# STEP 2: Read and preprocess the uploaded text file
filename = list(uploaded.keys())[0]

# Read file and skip the header
transactions = []
with open(filename, 'r') as file:
    lines = file.readlines()[1:]  # Skip header line
    for line in lines:
        parts = line.strip().split(',')
        # Skip Transaction ID, only keep items
        items = [item.strip().lower() for item in parts[1:] if item.strip()]
        transactions.append(items)

# STEP 3: Encode transactions into dataframe
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# STEP 4: Find frequent itemsets using FP-Growth
frequent_itemsets = fpgrowth(df, min_support=0.2, use_colnames=True)  # 20% support threshold
print("🔸 Frequent Itemsets with Support:")
print(frequent_itemsets.sort_values(by="support", ascending=False))

# STEP 5: Compute confidence and lift
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
print("\n🔹 Association Rules (Confidence >= 60%):")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].sort_values(by="lift", ascending=False))
# Out:
#      <input type="file" id="files-dc2a3efd-c8e4-4a3d-9804-7e2ac0623c4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc2a3efd-c8e4-4a3d-9804-7e2ac0623c4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Comparing Apriori and FP-Growth

# %%
from google.colab import files
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules
import time

# Upload file
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Read and process the .txt file
transactions = []
with open(filename, 'r') as file:
    lines = file.readlines()[1:]  # skip header
    for line in lines:
        parts = line.strip().split(',')
        items = [item.strip().lower() for item in parts[1:] if item.strip()]
        transactions.append(items)

# One-hot encoding
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_array, columns=te.columns_)

print("⚡ FP-Growth Results:")

start_fp = time.time()
fp_itemsets = fpgrowth(df, min_support=0.2, use_colnames=True)
end_fp = time.time()

print("\n🔸 Frequent Itemsets:")
print(fp_itemsets.sort_values(by="support", ascending=False))

fp_rules = association_rules(fp_itemsets, metric="confidence", min_threshold=0.6)
print("\n🔹 Association Rules (Confidence ≥ 60%):")
print(fp_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])

print(f"\n⏱️ FP-Growth Time: {end_fp - start_fp:.4f} seconds")

print("\n🔥 Apriori Results:")

start_ap = time.time()
ap_itemsets = apriori(df, min_support=0.2, use_colnames=True)
end_ap = time.time()

print("\n🔸 Frequent Itemsets:")
print(ap_itemsets.sort_values(by="support", ascending=False))

ap_rules = association_rules(ap_itemsets, metric="confidence", min_threshold=0.6)
print("\n🔹 Association Rules (Confidence ≥ 60%):")
print(ap_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])

print(f"\n⏱️ Apriori Time: {end_ap - start_ap:.4f} seconds")

summary = {
    "Algorithm": ["FP-Growth", "Apriori"],
    "Frequent Itemsets": [len(fp_itemsets), len(ap_itemsets)],
    "Rules (conf ≥ 0.6)": [len(fp_rules), len(ap_rules)],
    "Execution Time (s)": [round(end_fp - start_fp, 4), round(end_ap - start_ap, 4)],
}

print("\n📊 Summary Comparison:")
print(pd.DataFrame(summary))
# Out:
#      <input type="file" id="files-a241f1c0-37bc-4c9f-ac7c-6e2eb0b421a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a241f1c0-37bc-4c9f-ac7c-6e2eb0b421a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
